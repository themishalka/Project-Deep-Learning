# %%
import requests
import json
import os

# Create folder for downloads
os.makedirs("gbm_rnaseq", exist_ok=True)

# filters to find RNA-Seq files for TCGA-GBM
filters = {
    "op": "and",
    "content": [
        {"op": "=", "content": {"field": "cases.project.project_id", "value": "TCGA-GBM"}},
        {"op": "=", "content": {"field": "data_category", "value": "Transcriptome Profiling"}},
        {"op": "=", "content": {"field": "data_type", "value": "Gene Expression Quantification"}}
    ]
}

params = {
    "filters": json.dumps(filters),
    "fields": "file_id,file_name",
    "format": "JSON",
    "size": "10000"
}

response = requests.get("https://api.gdc.cancer.gov/files", params=params)
files = response.json()["data"]["hits"]

print(f"Found {len(files)} files")

# Download each file
for f in files:
    file_id = f["file_id"]
    file_name = f["file_name"]
    url = f"https://api.gdc.cancer.gov/data/{file_id}"

    print("Downloading:", file_name)
    r = requests.get(url, stream=True)
    with open(os.path.join("gbm_rnaseq", file_name), "wb") as out:
       for chunk in r.iter_content(chunk_size=8192):
         if chunk:
            out.write(chunk)
# Out:
# Found 391 files
# Downloading: 1ccc2b22-7f6c-4973-a6fa-f2c4d6be6dba.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 44aa45ef-4bcd-47eb-a2ef-68b614d00a51.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 967e6f4b-8c6b-4498-87c2-330b2c174061.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 2426bdbe-9a09-4ea1-b5eb-1ecb2c492898.rna_seq.augmented_star_gene_counts.tsv
# Downloading: d2b6a1a6-ed16-4374-8b28-912237ed87c2.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 520c0e78-f0a3-4e46-8c8e-00cf654e100d.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 229e6793-e11e-46c8-9307-1847243a311c.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 1f027bee-5316-4d9f-a566-41890da18493.rna_seq.augmented_star_gene_counts.tsv
# Downloading: e3ca6a99-2907-4509-a416-eb7362b0b606.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 2c3f2491-4d3b-41da-9866-94644fc8d102.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 69804564-72f3-443e-a45e-add43d917b2c.rna_seq.augmented_star_gene_counts.tsv
# Downloading: ce5fb607-99c5-457f-9022-df38b540fce6.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 113df549-f143-4c50-8e18-7c2159bda4eb.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 7753deb5-3885-44ca-be8b-8ff6ab9d7e30.rna_seq.augmented_star_gene_counts.tsv
# Downloading: a4e0b059-6e1e-4e90-b55a-4e043e6ed051.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 0b53e868-b960-466d-b435-f41a9a8ef34b.rna_seq.augmented_star_gene_counts.tsv
# Downloading: aab4bee0-b7a4-4671-b7e3-e11f11abe0e7.rna_seq.augmented_star_gene_counts.tsv
# Downloading: db0f3e8d-4a8e-48c7-8903-3dfba46d8401.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 1435785d-a1c3-4f05-a369-74a2134d5986.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 78484ab5-e8f8-4029-b5b2-63629a949e2f.rna_seq.augmented_star_gene_counts.tsv
# Downloading: d745289b-15ab-4923-9590-774b20d8b885.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 80f616bc-e28d-43b2-b3cb-606962c0d22b.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 58d714ce-bdb7-4365-b3f9-a5464237b1d4.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 2e33127c-779d-4f05-bbae-7893b9d27364.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 4a44bd40-1141-4524-a35f-f29ee37f6c63.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 0ce1eb02-a90c-484a-b861-c359562d3be1.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 9b1f39e2-a587-4fde-afd2-e0808a7766c1.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 5b1cc683-d363-4cb8-b9b2-050c3c541858.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 979a75fb-49bd-48e4-b7b1-1391a67726cb.rna_seq.augmented_star_gene_counts.tsv
# Downloading: c247006d-7749-4838-9bfb-1388e089450d.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 6b59c7e7-11f7-4326-a849-2e1a6bb9f3e7.rna_seq.augmented_star_gene_counts.tsv
# Downloading: e08e8902-f526-449f-b645-d29b06d175dd.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 6571f6d5-963a-4ff7-9174-2b4d61c11069.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 45ab4192-f1bb-46cd-8e85-c2341d67642f.rna_seq.augmented_star_gene_counts.tsv
# Downloading: dad61e18-e3f1-4beb-b3c3-ae434e35af2d.rna_seq.augmented_star_gene_counts.tsv
# Downloading:
rna_seq.augmented_star_gene_counts.tsv
# Downloading: 7fd5b083-8d24-4631-8c52-146c27197be2.rna_seq.augmented_star_gene_counts.tsv
# Downloading: 045a8628-9c12-4816-ae31-bad5ba0d784f.rna_seq.augmented_star_gene_counts.tsv

# %%
import os

#print(os.listdir("gbm_rnaseq")[:10])  # show first 10 files
#print(len(os.listdir("gbm_rnaseq")))  # should be 391

print(os.getcwd())
# Out:
# c:\Users\joann\AppData\Local\Programs\Microsoft VS Code

# %%
import pandas as pd
import glob
import os


# 1. Find all the TSV files in the gbm_rnaseq folder
files = glob.glob("gbm_rnaseq/*.tsv")
print(f"Found {len(files)} files")

# 2. This list will store one DataFrame per sample
data_frames = []

# 3. Loop over each file (one file ≈ one sample)
for file in files:
    # --- A. Read the STAR gene-count file ---
    # comment="#" tells pandas: "skip lines that start with #"
    df = pd.read_csv(file, sep="\t", comment="#")
    
    # --- B. Decide which column contains the counts ---
    # STAR 'augmented_star_gene_counts' files typically have columns:
    # gene_id, gene_name, unstranded, stranded_first, stranded_second, input
    # We want the 'unstranded' counts 
    if "unstranded" in df.columns:
        count_col = "unstranded"
    else:
        # Fallback: use the third column if for some reason the name is different
        count_col = df.columns[2]
    
    # --- C. Create a sample ID based on the filename ---
    # Example filename:
    # "1ccc2b22-7f6c-4973-a6fa-f2c4d6be6dba.rna_seq.augmented_star_gene_counts.tsv"
    # We take the part before the first dot (the UUID):
    sample_id = os.path.basename(file).split(".")[0]
    
    # --- D. Keep only gene_id and this sample's counts ---
    df = df[["gene_id", count_col]]
    
    # --- E. Remove non-gene summary rows ---
    # STAR adds rows like "__no_feature", "__ambiguous", etc.
    # These are not real genes and must be removed.
    df = df[~df["gene_id"].str.startswith("__")]
    
    # --- F. Set gene_id as the index (rows labeled by gene) ---
    df = df.set_index("gene_id")
    
    # --- G. Rename the count column to the sample_id ---
    # So instead of column name 'unstranded', it becomes that sample's ID
    df = df.rename(columns={count_col: sample_id})
    
    # --- H. Store this per-sample DataFrame for later concatenation ---
    data_frames.append(df)

# 4. Concatenate all sample DataFrames side-by-side by gene_id
# Because all dfs have the same index (gene_id), concat aligns by genes.
merged_df = pd.concat(data_frames, axis=1)

# 5. Print shape: (number_of_genes, number_of_samples)
print("Final expression matrix shape:", merged_df.shape)

# 6. Save to CSV
output_path = "gbm_rnaseq/merged_gbm_rnaseq.csv"
merged_df.to_csv(output_path)
print("Saved merged matrix to:", output_path)
# Out:
# Found 391 files
# Final expression matrix shape: (60664, 391)
# Saved merged matrix to: gbm_rnaseq/merged_gbm_rnaseq.csv

# %%
import requests
import json
import pandas as pd
# Step 1: Request all clinical records for TCGA-GBM
endpoint = "https://api.gdc.cancer.gov/cases"

filters = {
    "op": "in",
    "content": {
        "field": "project.project_id",
        "value": ["TCGA-GBM"]
    }
}

params = {
    "filters": json.dumps(filters),
    "fields": ",".join([
        "case_id",
        "submitter_id",
        "demographic.gender",
        "demographic.race",
        "demographic.ethnicity",
        "diagnoses.age_at_diagnosis",
        "diagnoses.days_to_death",
        "diagnoses.days_to_last_follow_up",
        "diagnoses.vital_status",
        "diagnoses.tumor_grade",
        "diagnoses.morphology",
        "diagnoses.primary_diagnosis"
    ]),
    "format": "JSON",
    "size": "10000"
}

response = requests.get(endpoint, params=params)
data = response.json()["data"]["hits"]

clinical_df = pd.json_normalize(data)
clinical_df.to_csv("clinical_gbm.csv", index=False)

print("Saved clinical metadata with shape:", clinical_df.shape)
clinical_df.head()
# Out:
# Saved clinical metadata with shape: (617, 7)
#                                      id                               case_id  \
# 0  025a7401-a65d-4ea0-8b4e-0ba775b0322a  025a7401-a65d-4ea0-8b4e-0ba775b0322a
# 1  e3711a9b-6d4c-44df-bbab-0a675046a5df  e3711a9b-6d4c-44df-bbab-0a675046a5df
# 2  cc1459be-de8f-482e-9efe-65937db9dc45  cc1459be-de8f-482e-9efe-65937db9dc45
# 3  d75996d6-9f02-4478-a4a1-dfa7ab41de77  d75996d6-9f02-4478-a4a1-dfa7ab41de77
# 4  883dc176-925a-44f7-9ec8-e0cce33c2a54  883dc176-925a-44f7-9ec8-e0cce33c2a54
#
#    submitter_id                                          diagnoses  \
# 0  TCGA-12-0819  [{'age_at_diagnosis': 18588, 'primary_diagnosi...
# 1  TCGA-06-0208  [{'age_at_diagnosis': 19257, 'primary_diagnosi...
# 2  TCGA-12-1601  [{'days_to_last_follow_up': None, 'age_at_diag...
# 3  TCGA-06-0131  [{'days_to_last_follow_up': None, 'age_at_diag...
# 4  TCGA-02-0099  [{'days_to_last_follow_up': 106.0, 'age_at_dia...
#
#             demographic.race demographic.gender   demographic.ethnicity
# 0  black or african american             female  not hispanic or latino
# 1                      white             female  not hispanic or latino
# 2               not reported       not reported            not reported
# 3               not reported       not reported            not reported
# 4                      white               male  not hispanic or latino

# %%
#visualize rna-seq file 
import pandas as pd
import glob
import os
os.chdir(r"C:/Users/joann/AppData/Local/Programs/Microsoft VS Code")


files = glob.glob("gbm_rnaseq/*.tsv")
sample_file = files[0]   # take the first file
print(sample_file)

df = pd.read_csv(sample_file, sep="\t", comment="#")
df.head(10)
# Out:
# gbm_rnaseq\006b091b-3a7a-4a26-9eb6-d7797874ad9b.rna_seq.augmented_star_gene_counts.tsv
#               gene_id gene_name       gene_type  unstranded  stranded_first  \
# 0          N_unmapped       NaN             NaN     4044353         4044353
# 1      N_multimapping       NaN             NaN    14331323        14331323
# 2         N_noFeature       NaN             NaN    26589531        93361615
# 3         N_ambiguous       NaN             NaN    13803893          113272
# 4  ENSG00000000003.15    TSPAN6  protein_coding        4281               1
# 5   ENSG00000000005.6      TNMD  protein_coding          21              12
# 6  ENSG00000000419.13      DPM1  protein_coding         923              15
# 7  ENSG00000000457.14     SCYL3  protein_coding        1056             324
# 8  ENSG00000000460.17  C1orf112  protein_coding         577             261
# 9  ENSG00000000938.13       FGR  protein_coding         458               3
#
#    stranded_second  tpm_unstranded  fpkm_unstranded  fpkm_uq_unstranded
# 0          4044353             NaN              NaN                 NaN
# 1         14331323             NaN              NaN                 NaN
# 2         27503197             NaN              NaN                 NaN
# 3         10907055             NaN              NaN                 NaN
# 4             4282         43.1334          18.2247             17.0320
# 5                9          0.6502           0.2747              0.2568
# 6              908         34.9491          14.7666             13.8003
# 7             1157          7.0118           2.9626              2.7687
# 8              780          4.4172           1.8663              1.7442
# 9              455          6.1892           2.6150              2.4439

# %%
#visualize expression matrix

expr = pd.read_csv("gbm_rnaseq/merged_gbm_rnaseq.csv", index_col=0)
expr.shape
expr.head()
expr.iloc[:10, :10]   # first 5 genes × first 5 samples
# Out:
#                     006b091b-3a7a-4a26-9eb6-d7797874ad9b  \
# gene_id
# N_unmapped                                       4044353
# N_multimapping                                  14331323
# N_noFeature                                     26589531
# N_ambiguous                                     13803893
# ENSG00000000003.15                                  4281
# ENSG00000000005.6                                     21
# ENSG00000000419.13                                   923
# ENSG00000000457.14                                  1056
# ENSG00000000460.17                                   577
# ENSG00000000938.13                                   458
#
#                     0257f378-cf6a-42f2-9cb1-0d10b4ca1b9a  \
# gene_id
# N_unmapped                                       5339128
# N_multimapping                                  16653665
# N_noFeature                                     15661372
# N_ambiguous                                     15990187
# ENSG00000000003.15                                  2030
# ENSG00000000005.6                                     20
# ENSG00000000419.13                                  1020
# ENSG00000000457.14                                  1431
# ENSG00000000460.17                                  1111
# ENSG00000000938.13                                   530
#
#                     026ed595-4218-4379-8e2d-54b390cb2544  \
# gene_id
# N_unmapped                                       6380180
# N_multimapping                                  19153916
# N_noFeature                                     15602661
# N_ambiguous                                     11210790
# ENSG00000000003.15                                  4150
# ENSG00000000005.6                                      2
# ENSG00000000419.13                                  1107
# ENSG00000000457.14                                  1006
# ENSG00000000460.17                                   673
# ENSG00000000938.13                                   532
#
#                     034c42f2-fee6-4196-9c02-24589ce01071  \
# gene_id
# N_unmapped                                       4124177
# N_multimapping                                  15701391
# N_noFeature                                     23206565
# N_ambiguous                                     12030266
# ENSG00000000003.15                                  1380
# ENSG00000000005.6                                      9
# ENSG00000000419.13                                   994
# ENSG00000000457.14                                   677
# ENSG00000000460.17                                   415
# ENSG00000000938.13                                   571
#
#                     03ddea6f-d377-4e2a-a59d-91d5c5b6e4ed  \
# gene_id
# N_unmapped                                       6961328
# N_multimapping                                   4419194
# N_noFeature                                      1891287
# N_ambiguous                                      6484715
# ENSG00000000003.15                                   361
# ENSG00000000005.6                                     26
# ENSG00000000419.13                                  1893
# ENSG00000000457.14                                   647
# ENSG00000000460.17                                   352
# ENSG00000000938.13                                   314
#
#                     045a8628-9c12-4816-ae31-bad5ba0d784f  \
# gene_id
# N_unmapped                                       6493356
# N_multimapping                                  11385005
# N_noFeature                                     34334638
# N_ambiguous                                     11647660
# ENSG00000000003.15                                  1615
# ENSG00000000005.6                                  25386
# ENSG00000000419.13                                  1041
# ENSG00000000457.14                                  1002
# ENSG00000000460.17                                   513
# ENSG00000000938.13                                  1041
#
#                     04b6d829-b031-4d9b-99cd-7f9007227edd  \
# gene_id
# N_unmapped                                       6575531
# N_multimapping                                  35093405
# N_noFeature                                      9511456
# N_ambiguous                                     18753690
# ENSG00000000003.15                                   633
# ENSG00000000005.6                                      8
# ENSG00000000419.13                                   468
# ENSG00000000457.14                                   515
# ENSG00000000460.17                                   324
# ENSG00000000938.13                                   692
#
#                     051dc36f-47e2-4d77-b9b9-c5f2d315f5f3  \
# gene_id
# N_unmapped                                       7431873
# N_multimapping                                   4539648
# N_noFeature                                      1450084
# N_ambiguous                                      4828004
# ENSG00000000003.15                                  5935
# ENSG00000000005.6                                     10
# ENSG00000000419.13                                  1447
# ENSG00000000457.14                                   478
# ENSG00000000460.17                                   213
# ENSG00000000938.13                                  1085
#
#                     05d2774d-cb3e-4485-9825-c04d4ca44bb6  \
# gene_id
# N_unmapped                                       6489128
# N_multimapping                                  26634100
# N_noFeature                                     15495803
# N_ambiguous                                     20607621
# ENSG00000000003.15                                  3159
# ENSG00000000005.6                                      9
# ENSG00000000419.13                                   742
# ENSG00000000457.14                                   821
# ENSG00000000460.17                                   436
# ENSG00000000938.13                                   228
#
#                     0601cab0-163f-48e4-bc9f-87b068d8b591
# gene_id
# N_unmapped                                       6831224
# N_multimapping                                  14771366
# N_noFeature                                     42653744
# N_ambiguous                                     12461464
# ENSG00000000003.15                                  3340
# ENSG00000000005.6                                     13
# ENSG00000000419.13                                  1119
# ENSG00000000457.14                                  1246
# ENSG00000000460.17                                  1056
# ENSG00000000938.13                                   490

# %%
#visualize clinical metadata 
clinical = pd.read_csv("C:/Users/joann/Desktop/M2/Deep_Learning/clinical_gbm.csv")
clinical.shape
clinical.head()
# Out:
#                                      id                               case_id  \
# 0  025a7401-a65d-4ea0-8b4e-0ba775b0322a  025a7401-a65d-4ea0-8b4e-0ba775b0322a
# 1  e3711a9b-6d4c-44df-bbab-0a675046a5df  e3711a9b-6d4c-44df-bbab-0a675046a5df
# 2  cc1459be-de8f-482e-9efe-65937db9dc45  cc1459be-de8f-482e-9efe-65937db9dc45
# 3  d75996d6-9f02-4478-a4a1-dfa7ab41de77  d75996d6-9f02-4478-a4a1-dfa7ab41de77
# 4  883dc176-925a-44f7-9ec8-e0cce33c2a54  883dc176-925a-44f7-9ec8-e0cce33c2a54
#
#    submitter_id                                          diagnoses  \
# 0  TCGA-12-0819  [{'age_at_diagnosis': 18588, 'primary_diagnosi...
# 1  TCGA-06-0208  [{'age_at_diagnosis': 19257, 'primary_diagnosi...
# 2  TCGA-12-1601  [{'days_to_last_follow_up': None, 'age_at_diag...
# 3  TCGA-06-0131  [{'days_to_last_follow_up': None, 'age_at_diag...
# 4  TCGA-02-0099  [{'days_to_last_follow_up': 106.0, 'age_at_dia...
#
#             demographic.race demographic.gender   demographic.ethnicity
# 0  black or african american             female  not hispanic or latino
# 1                      white             female  not hispanic or latino
# 2               not reported       not reported            not reported
# 3               not reported       not reported            not reported
# 4                      white               male  not hispanic or latino
