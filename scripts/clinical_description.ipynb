# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Investigating the available clinical data
#
# In this script, we will explore the clinical information available from the TCGA glioblastoma (GBM) transcriptome profiling (391 files).
# We aim to understand which clinical metadata is publically available to guide our analysis.

# %%
# loading data
clinical = pd.read_csv("../data/clinical_gbm.csv")
clinical.head()
# Out:
#                                      id                               case_id  \
# 0  025a7401-a65d-4ea0-8b4e-0ba775b0322a  025a7401-a65d-4ea0-8b4e-0ba775b0322a
# 1  e3711a9b-6d4c-44df-bbab-0a675046a5df  e3711a9b-6d4c-44df-bbab-0a675046a5df
# 2  cc1459be-de8f-482e-9efe-65937db9dc45  cc1459be-de8f-482e-9efe-65937db9dc45
# 3  d75996d6-9f02-4478-a4a1-dfa7ab41de77  d75996d6-9f02-4478-a4a1-dfa7ab41de77
# 4  883dc176-925a-44f7-9ec8-e0cce33c2a54  883dc176-925a-44f7-9ec8-e0cce33c2a54
#
#    submitter_id                                          diagnoses  \
# 0  TCGA-12-0819  [{'age_at_diagnosis': 18588, 'primary_diagnosi...
# 1  TCGA-06-0208  [{'age_at_diagnosis': 19257, 'primary_diagnosi...
# 2  TCGA-12-1601  [{'days_to_last_follow_up': None, 'age_at_diag...
# 3  TCGA-06-0131  [{'days_to_last_follow_up': None, 'age_at_diag...
# 4  TCGA-02-0099  [{'days_to_last_follow_up': 106.0, 'age_at_dia...
#
#             demographic.race demographic.gender   demographic.ethnicity
# 0  black or african american             female  not hispanic or latino
# 1                      white             female  not hispanic or latino
# 2               not reported       not reported            not reported
# 3               not reported       not reported            not reported
# 4                      white               male  not hispanic or latino

# %%
# column submitter_id
print(clinical["submitter_id"].unique())
print(len(clinical["submitter_id"]))
# Out:
# ['TCGA-12-0819' 'TCGA-06-0208' 'TCGA-12-1601' 'TCGA-06-0131'
#  'TCGA-02-0099' 'TCGA-02-2470' 'TCGA-02-0024' 'TCGA-06-0154'
#  'TCGA-27-1838' 'TCGA-06-0210' 'TCGA-06-0128' 'TCGA-06-0133'
#  'TCGA-14-1451' 'TCGA-06-0124' 'TCGA-14-3476' 'TCGA-02-0028'
#  'TCGA-06-0145' 'TCGA-06-0130' 'TCGA-06-0129' 'TCGA-06-0127'
#  'TCGA-16-1045' 'TCGA-02-0114' 'TCGA-12-0615' 'TCGA-27-2526'
#  'TCGA-06-0211' 'TCGA-15-1449' 'TCGA-06-0126' 'TCGA-06-6391'
#  'TCGA-06-0189' 'TCGA-06-0147' 'TCGA-06-0125' 'TCGA-06-0132'
#  'TCGA-14-1454' 'TCGA-02-0107' 'TCGA-32-2495' 'TCGA-06-0148'
#  'TCGA-06-0139' 'TCGA-32-2498' 'TCGA-02-0058' 'TCGA-06-0119'
#  'TCGA-12-0653' 'TCGA-06-0209' 'TCGA-28-2512' 'TCGA-02-0010'
#  'TCGA-12-0662' 'TCGA-06-0159' 'TCGA-19-5953' 'TCGA-06-0176'
#  'TCGA-02-0089' 'TCGA-16-1047' 'TCGA-02-0021' 'TCGA-06-0744'
#  'TCGA-02-0023' 'TCGA-4W-AA9S' 'TCGA-06-2557' 'TCGA-12-0769'
#  'TCGA-06-0237' 'TCGA-02-0001' 'TCGA-06-0121' 'TCGA-26-1442'
#  'TCGA-14-0865' 'TCGA-19-5956' 'TCGA-06-6388' 'TCGA-19-2619'
#  'TCGA-19-5958' 'TCGA-06-A6S0' 'TCGA-28-6450' 'TCGA-02-0014'
#  'TCGA-16-1055' 'TCGA-06-6694' 'TCGA-08-0353' 'TCGA-14-1823'
#  'TCGA-06-0165' 'TCGA-16-0861' 'TCGA-12-1602' 'TCGA-76-6191'
#  'TCGA-06-5413' 'TCGA-12-0691' 'TCGA-26-6173' 'TCGA-02-0102'
#  'TCGA-02-0086' 'TCGA-26-5132' 'TCGA-02-0007' 'TCGA-08-0351'
#  'TCGA-06-0185' 'TCGA-06-1804' 'TCGA-06-2564' 'TCGA-06-0151'
#  'TCGA-76-6663' 'TCGA-RR-A6KA' 'TCGA-12-3649' 'TCGA-02-0338'
#  'TCGA-02-0289' 'TCGA-12-0829' 'TCGA-14-1453' 'TCGA-06-0197'
#  'TCGA-06-1086' 'TCGA-41-2572' 'TCGA-76-6664' 'TCGA-14-2555'
#  'TCGA-06-0214' 'TCGA-4W-AA9T' 'TCGA-74-6577' 'TCGA-06-0412'
#  'TCGA-06-1087' 'TCGA-RR-A6KB' 'TCGA-06-0878' 'TCGA-32-1991'
#  'TCGA-19-2621' 'TCGA-06-0164' 'TCGA-14-0781' 'TCGA-76-4925'
#  'TCGA-06-1805' 'TCGA-06-0240' 'TCGA-02-0027' 'TCGA-06-0194'
#  'TCGA-14-0787' 'TCGA-08-0354' 'TCGA-14-1455' 'TCGA-19-4065'
#  'TCGA-06-0221' 'TCGA-02-0321' 'TCGA-81-5911' 'TCGA-15-1446'
#  'TCGA-06-0678' 'TCGA-06-6695' 'TCGA-08-0349' 'TCGA-08-0510'
#  'TCGA-08-0352' 'TCGA-14-1459' 'TCGA-02-0071' 'TCGA-02-0451'
#  'TCGA-76-6286' 'TCGA-26-1439' 'TCGA-06-A7TL' 'TCGA-08-0373'
#  'TCGA-14-1456' 'TCGA-06-0216' 'TCGA-41-6646' 'TCGA-08-0390'
#  'TCGA-76-6193' 'TCGA-41-2573' 'TCGA-12-0780' 'TCGA-08-0529'
#  'TCGA-02-0336' 'TCGA-14-1396' 'TCGA-12-1600' 'TCGA-06-1084'
#  'TCGA-06-1802' 'TCGA-12-0822' 'TCGA-19-5955' 'TCGA-12-3652'
#  'TCGA-06-0675' 'TCGA-19-0963' 'TCGA-06-2566' 'TCGA-19-1790'
#  'TCGA-12-1090' 'TCGA-19-5954' 'TCGA-06-0213' 'TCGA-19-A6J4'
#  'TCGA-06-0413' 'TCGA-08-0516' 'TCGA-08-0244' 'TCGA-08-0525'
#  'TCGA-14-2554' 'TCGA-06-0881' 'TCGA-06-AABW' 'TCGA-06-2570'
#  'TCGA-02-0339' 'TCGA-28-2501' 'TCGA-02-0039' 'TCGA-12-0827'
#  'TCGA-02-0250' 'TCGA-26-5134' 'TCGA-28-1753' 'TCGA-06-0882'
#  'TCGA-06-0182' 'TCGA-06-0175' 'TCGA-32-4213' 'TCGA-27-1837'
#  'TCGA-06-0169' 'TCGA-08-0514' 'TCGA-06-0177' 'TCGA-06-0680'
#  'TCGA-14-0783' 'TCGA-02-0074' 'TCGA-74-6581' 'TCGA-06-0397'
#  'TCGA-28-5204' 'TCGA-12-1598' 'TCGA-06-6698' 'TCGA-41-2575'
#  'TCGA-08-0626' 'TCGA-02-0085' 'TCGA-12-0776' 'TCGA-02-0009'
#  'TCGA-12-3653' 'TCGA-19-1387' 'TCGA-32-1982' 'TCGA-02-2466'
#  'TCGA-08-0509' 'TCGA-28-2513' 'TCGA-12-0656' 'TCGA-28-1746'
#  'TCGA-08-0531' 'TCGA-02-0011' 'TCGA-06-0686' 'TCGA-28-2514'
#  'TCGA-19-2620' 'TCGA-06-0143' 'TCGA-12-0772' 'TCGA-76-6657'
#  'TCGA-06-0745' 'TCGA-02-0068' 'TCGA-14-0736' 'TCGA-08-0623'
#  'TCGA-14-4157' 'TCGA-14-1821' 'TCGA-28-5211' 'TCGA-06-5858'
#  'TCGA-02-0037' 'TCGA-19-1789' 'TCGA-76-4934' 'TCGA-27-2518'
#  'TCGA-06-6390' 'TCGA-06-5411' 'TCGA-32-1980' 'TCGA-19-1786'
#  'TCGA-32-1977' 'TCGA-19-5959' 'TCGA-02-0281' 'TCGA-41-3915'
#  'TCGA-19-A60I' 'TCGA-06-0747' 'TCGA-28-5207' 'TCGA-06-0162'
#  'TCGA-06-5859' 'TCGA-28-5208' 'TCGA-02-0285' 'TCGA-41-3392'
#  'TCGA-27-1832' 'TCGA-08-0392' 'TCGA-06-0166' 'TCGA-06-0141'
#  'TCGA-76-4928' 'TCGA-14-1825' 'TCGA-74-6578' 'TCGA-02-0054'
#  'TCGA-08-0348' 'TCGA-32-2632' 'TCGA-06-2562' 'TCGA-02-0326'
#  'TCGA-06-A6S1' 'TCGA-26-1443' 'TCGA-06-5418' 'TCGA-08-0522'
#  'TCGA-32-4210' 'TCGA-02-0079' 'TCGA-32-5222' 'TCGA-12-3646'
#  'TCGA-06-0749' 'TCGA-08-0520' 'TCGA-16-0848' 'TCGA-06-0646'
#  'TCGA-08-0524' 'TCGA-08-0389' 'TCGA-12-0821' 'TCGA-02-0324'
#  'TCGA-08-0346' 'TCGA-28-2506' 'TCGA-08-0358' 'TCGA-06-2567'
#  'TCGA-87-5896' 'TCGA-28-5219' 'TCGA-08-0345' 'TCGA-06-0238'
#  'TCGA-19-5952' 'TCGA-32-1987' 'TCGA-02-0052' 'TCGA-06-0648'
#  'TCGA-14-0812' 'TCGA-12-3650' 'TCGA-26-A7UX' 'TCGA-02-0329'
#  'TCGA-06-0192' 'TCGA-14-3477' 'TCGA-14-1401' 'TCGA-19-5951'
#  'TCGA-14-1827' 'TCGA-27-1833' 'TCGA-06-0644' 'TCGA-19-0955'
#  'TCGA-02-0325' 'TCGA-06-5856' 'TCGA-4W-AA9R' 'TCGA-06-0152'
#  'TCGA-06-0649' 'TCGA-12-1097' 'TCGA-08-0356' 'TCGA-06-0173'
#  'TCGA-12-0670' 'TCGA-02-0317' 'TCGA-28-1752' 'TCGA-02-0034'
#  'TCGA-02-0015' 'TCGA-26-5135' 'TCGA-14-1037' 'TCGA-02-0033'
#  'TCGA-02-0038' 'TCGA-76-6280' 'TCGA-28-2510' 'TCGA-06-0241'
#  'TCGA-19-1392' 'TCGA-08-0360' 'TCGA-06-0409' 'TCGA-16-1063'
#  'TCGA-27-1830' 'TCGA-41-3393' 'TCGA-08-0380' 'TCGA-14-0740'
#  'TCGA-02-0258' 'TCGA-06-5415' 'TCGA-32-4719' 'TCGA-41-2571'
#  'TCGA-14-0871' 'TCGA-28-5213' 'TCGA-27-1834' 'TCGA-02-0069'
#  'TCGA-06-0190' 'TCGA-14-1395' 'TCGA-19-0964' 'TCGA-02-0051'
#  'TCGA-02-0290' 'TCGA-02-0430' 'TCGA-06-5417' 'TCGA-06-0142'
#  'TCGA-76-4931' 'TCGA-76-6656' 'TCGA-12-0775' 'TCGA-08-0512'
#  'TCGA-12-1093' 'TCGA-02-0330' 'TCGA-02-2486' 'TCGA-06-0676'
#  'TCGA-06-5414' 'TCGA-02-0057' 'TCGA-32-1986' 'TCGA-16-1460'
#  'TCGA-14-0789' 'TCGA-06-0138' 'TCGA-14-1795' 'TCGA-06-0156'
#  'TCGA-02-0083' 'TCGA-14-0790' 'TCGA-06-0394' 'TCGA-06-0178'
#  'TCGA-06-A5U1' 'TCGA-06-0168' 'TCGA-12-1095' 'TCGA-06-6700'
#  'TCGA-28-2499' 'TCGA-02-0070' 'TCGA-15-1444' 'TCGA-06-0645'
#  'TCGA-32-4209' 'TCGA-76-4935' 'TCGA-06-0140' 'TCGA-06-5410'
#  'TCGA-27-2523' 'TCGA-19-5947' 'TCGA-08-0375' 'TCGA-06-0137'
#  'TCGA-02-0080' 'TCGA-74-6573' 'TCGA-02-0055' 'TCGA-02-0116'
#  'TCGA-02-0113' 'TCGA-02-0043' 'TCGA-28-2502' 'TCGA-76-4926'
#  'TCGA-28-5220' 'TCGA-26-6174' 'TCGA-12-0818' 'TCGA-76-6662'
#  'TCGA-06-0187' 'TCGA-19-5960' 'TCGA-32-2616' 'TCGA-16-1060'
#  'TCGA-12-0707' 'TCGA-19-A6J5' 'TCGA-08-0517' 'TCGA-OX-A56R'
#  'TCGA-06-6699' 'TCGA-06-0750' 'TCGA-02-0006' 'TCGA-19-0960'
#  'TCGA-32-1978' 'TCGA-27-1835' 'TCGA-27-2519' 'TCGA-14-1829'
#  'TCGA-06-0875' 'TCGA-28-1747' 'TCGA-19-1788' 'TCGA-02-0087'
#  'TCGA-26-1440' 'TCGA-76-4927' 'TCGA-76-6285' 'TCGA-14-1034'
#  'TCGA-06-1806' 'TCGA-12-1098' 'TCGA-06-0171' 'TCGA-06-0402'
#  'TCGA-16-0849' 'TCGA-12-0619' 'TCGA-15-1447' 'TCGA-26-5133'
#  'TCGA-02-2483' 'TCGA-19-0957' 'TCGA-27-2524' 'TCGA-16-1062'
#  'TCGA-02-0111' 'TCGA-27-2527' 'TCGA-12-0703' 'TCGA-08-0359'
#  'TCGA-28-1756' 'TCGA-81-5910' 'TCGA-12-1099' 'TCGA-14-1043'
#  'TCGA-19-1385' 'TCGA-32-2634' 'TCGA-02-0333' 'TCGA-06-0414'
#  'TCGA-02-0446' 'TCGA-12-0657' 'TCGA-06-0160' 'TCGA-12-5301'
#  'TCGA-28-2509' 'TCGA-14-0786' 'TCGA-19-2631' 'TCGA-06-6701'
#  'TCGA-08-0511' 'TCGA-12-1088' 'TCGA-32-2491' 'TCGA-28-5209'
#  'TCGA-06-0122' 'TCGA-02-0016' 'TCGA-12-1599' 'TCGA-19-1388'
#  'TCGA-26-1438' 'TCGA-06-5408' 'TCGA-02-0337' 'TCGA-06-0167'
#  'TCGA-12-1096' 'TCGA-32-1979' 'TCGA-76-6661' 'TCGA-02-0075'
#  'TCGA-32-2638' 'TCGA-02-0439' 'TCGA-06-1800' 'TCGA-06-6697'
#  'TCGA-08-0521' 'TCGA-12-0620' 'TCGA-28-1745' 'TCGA-02-0432'
#  'TCGA-06-0184' 'TCGA-19-0962' 'TCGA-28-1760' 'TCGA-28-1749'
#  'TCGA-06-2563' 'TCGA-08-0355' 'TCGA-74-6584' 'TCGA-06-0158'
#  'TCGA-12-0692' 'TCGA-02-0048' 'TCGA-06-0219' 'TCGA-06-1801'
#  'TCGA-27-2528' 'TCGA-06-0149' 'TCGA-08-0344' 'TCGA-14-1402'
#  'TCGA-28-1751' 'TCGA-08-0385' 'TCGA-19-2623' 'TCGA-12-1597'
#  'TCGA-76-4929' 'TCGA-41-5651' 'TCGA-19-2624' 'TCGA-28-5216'
#  'TCGA-14-0866' 'TCGA-32-2615' 'TCGA-06-0146' 'TCGA-76-6282'
#  'TCGA-19-1389' 'TCGA-32-2494' 'TCGA-08-0386' 'TCGA-14-0862'
#  'TCGA-06-0876' 'TCGA-06-0877' 'TCGA-02-0260' 'TCGA-06-2565'
#  'TCGA-26-5136' 'TCGA-12-5295' 'TCGA-02-0115' 'TCGA-28-5215'
#  'TCGA-12-0820' 'TCGA-06-2559' 'TCGA-02-0266' 'TCGA-28-5214'
#  'TCGA-14-0813' 'TCGA-06-0939' 'TCGA-16-0850' 'TCGA-06-2558'
#  'TCGA-32-1976' 'TCGA-02-0269' 'TCGA-02-0106' 'TCGA-02-0064'
#  'TCGA-06-5416' 'TCGA-02-0004' 'TCGA-28-1755' 'TCGA-06-6693'
#  'TCGA-02-0047' 'TCGA-12-3651' 'TCGA-16-1048' 'TCGA-28-5218'
#  'TCGA-12-3648' 'TCGA-08-0625' 'TCGA-06-A7TK' 'TCGA-06-2561'
#  'TCGA-76-4932' 'TCGA-02-0026' 'TCGA-26-5139' 'TCGA-06-6389'
#  'TCGA-19-1787' 'TCGA-12-0828' 'TCGA-02-0104' 'TCGA-12-0778'
#  'TCGA-08-0347' 'TCGA-08-0350' 'TCGA-12-1094' 'TCGA-27-2521'
#  'TCGA-76-6660' 'TCGA-02-0003' 'TCGA-12-0773' 'TCGA-12-1092'
#  'TCGA-06-0206' 'TCGA-06-0673' 'TCGA-02-0456' 'TCGA-27-1836'
#  'TCGA-02-0422' 'TCGA-19-2629' 'TCGA-12-1089' 'TCGA-02-0440'
#  'TCGA-06-0743' 'TCGA-RR-A6KC' 'TCGA-06-0410' 'TCGA-32-4211'
#  'TCGA-76-6283' 'TCGA-12-0654' 'TCGA-08-0245' 'TCGA-06-5412'
#  'TCGA-02-2485' 'TCGA-06-0650' 'TCGA-16-1056' 'TCGA-19-1390'
#  'TCGA-12-5299' 'TCGA-06-0157' 'TCGA-16-0846' 'TCGA-08-0357'
#  'TCGA-02-0332' 'TCGA-14-1794' 'TCGA-19-5950' 'TCGA-12-0616'
#  'TCGA-28-1757' 'TCGA-06-0174' 'TCGA-32-4208' 'TCGA-19-4068'
#  'TCGA-14-0817' 'TCGA-02-0084' 'TCGA-02-0046' 'TCGA-08-0627'
#  'TCGA-14-0867' 'TCGA-14-1458' 'TCGA-28-1750' 'TCGA-06-A5U0'
#  'TCGA-15-0742' 'TCGA-06-0150' 'TCGA-14-1450' 'TCGA-06-0179'
#  'TCGA-06-2569' 'TCGA-02-0271' 'TCGA-08-0518' 'TCGA-27-1831'
#  'TCGA-06-0188' 'TCGA-12-0688' 'TCGA-02-0025' 'TCGA-19-1791'
#  'TCGA-74-6575' 'TCGA-41-4097' 'TCGA-08-0246' 'TCGA-19-2625'
#  'TCGA-12-3644' 'TCGA-32-1973' 'TCGA-06-0195' 'TCGA-06-0681'
#  'TCGA-02-0060' 'TCGA-12-0618' 'TCGA-76-6192' 'TCGA-14-1452'
#  'TCGA-12-1091' 'TCGA-06-0879' 'TCGA-06-0155' 'TCGA-02-0059'
#  'TCGA-19-1386' 'TCGA-32-1970' 'TCGA-06-0201' 'TCGA-12-0826'
#  'TCGA-26-1799']
# 617

# %%
# column diagnoses 
print(clinical["diagnoses"][0])
print(clinical["diagnoses"][1])
print(clinical["diagnoses"][2])
# Out:
# [{'age_at_diagnosis': 18588, 'primary_diagnosis': 'Glioblastoma', 'morphology': '9440/3'}, {'days_to_last_follow_up': 754.0, 'age_at_diagnosis': 18160, 'primary_diagnosis': 'Glioblastoma', 'morphology': '9440/3', 'tumor_grade': None}]
# [{'age_at_diagnosis': 19257, 'primary_diagnosis': 'Glioblastoma', 'morphology': '9440/3'}, {'days_to_last_follow_up': 256.0, 'age_at_diagnosis': 19108, 'primary_diagnosis': 'Glioblastoma', 'morphology': '9440/3', 'tumor_grade': None}]
# [{'days_to_last_follow_up': None, 'age_at_diagnosis': None, 'primary_diagnosis': 'Glioblastoma', 'morphology': '9440/3', 'tumor_grade': 'Not Reported'}]

# %%
# column demographic race 
print(clinical["demographic.race"].unique())
print(clinical["demographic.race"].value_counts())
# Out:
# ['black or african american' 'white' 'not reported' 'asian' nan]
# demographic.race
# white                        507
# black or african american     51
# not reported                  29
# asian                         13
# Name: count, dtype: int64

# %%
# column demographic gender
print(clinical["demographic.gender"].unique())
print(clinical["demographic.gender"].value_counts())
# Out:
# ['female' 'not reported' 'male' nan]
# demographic.gender
# male            366
# female          230
# not reported      4
# Name: count, dtype: int64

# %%
# column demographic ethnicity 
print(clinical["demographic.ethnicity"].unique())
print(clinical["demographic.ethnicity"].value_counts())
# Out:
# ['not hispanic or latino' 'not reported' nan 'hispanic or latino']
# demographic.ethnicity
# not hispanic or latino    490
# not reported               97
# hispanic or latino         13
# Name: count, dtype: int64
